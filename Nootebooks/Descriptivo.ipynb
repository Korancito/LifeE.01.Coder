# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# Comenzamos cargando el source del csv a utilizar.
# Elegimos Life Expectancy

# %%
df = pd.read_csv('C:/Users/fksob/OneDrive/CoderHouse - Data Science/LifeE.Coder.01/Source/Lifeexpectancydata.csv')

# %% [markdown]
#
# Obtenemos informacion preliminar de las columnas y su contenido

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# Establecemos nuevos nombres a nuestras columnas para mejor manejo de la informacion

# %%
rename_columns = {
    'Country': 'País',
    'Year': 'Año',
    'Status': 'Estado de desarrollo',
    'Life expectancy ': 'Esperanza de vida',
    'Adult Mortality': 'Mortalidad adulta',
    'infant deaths': 'Muertes infantiles',
    'Alcohol': 'Alcohol',
    'percentage expenditure': 'Gasto porcentual',
    'Hepatitis B': 'Hepatitis B',
    'Measles ': 'Sarampión',
    ' BMI ': 'IMC',
    'under-five deaths ': 'Muertes menores de cinco años',
    'Polio': 'Polio',
    'Total expenditure': 'Gasto total',
    'Diphtheria ': 'Difteria',
    ' HIV/AIDS': 'VIH/SIDA',
    'GDP': 'PIBPC',
    'Population': 'Población',
    ' thinness  1-19 years': 'Delgadez 1-19 años',
    ' thinness 5-9 years': 'Delgadez 5-9 años',
    'Income composition of resources': 'Indice de desarrollo humano',
    'Schooling': 'Escolaridad'
}

# %% [markdown]
# Definimos un dataframe nuevo para remplazar los nombres de nuestras columnas.

# %%
df01 = df
dfrenamed = df01.rename(columns=rename_columns)
dfrenamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   País                           2938 non-null   object
#  1   Año                            2938 non-null   int64
#  2   Estado de desarrollo           2938 non-null   object
#  3   Esperanza de vida              2928 non-null   float64
#  4   Mortalidad adulta              2928 non-null   float64
#  5   Muertes infantiles             2938 non-null   int64
#  6   Alcohol                        2744 non-null   float64
#  7   Gasto porcentual               2938 non-null   float64
#  8   Hepatitis B                    2385 non-null   float64
#  9   Sarampión                      2938 non-null   int64
#  10  IMC                            2904 non-null   float64
#  11  Muertes menores de cinco años  2938 non-null   int64
# ...

# %% [markdown]
# Observamos y corregimos nulls de nuestro cvs

# %%
dfrenamed.isnull().sum()
# Out:
# País                               0
# Año                                0
# Estado de desarrollo               0
# Esperanza de vida                 10
# Mortalidad adulta                 10
# Muertes infantiles                 0
# Alcohol                          194
# Gasto porcentual                   0
# Hepatitis B                      553
# Sarampión                          0
# IMC                               34
# Muertes menores de cinco años      0
# Polio                             19
# Gasto total                      226
# Difteria                          19
# VIH/SIDA                           0
# PIBPC                            448
# Población                        652
# Delgadez 1-19 años                34
# Delgadez 5-9 años                 34
# Indice de desarrollo humano      167
# Escolaridad                      163
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None)

dfrenamed['Esperanza de vida'] = imputer.fit_transform(dfrenamed[['Esperanza de vida']])
dfrenamed['Mortalidad adulta'] = imputer.fit_transform(dfrenamed[['Mortalidad adulta']])
dfrenamed['Alcohol'] = imputer.fit_transform(dfrenamed[['Alcohol']])
dfrenamed['Hepatitis B'] = imputer.fit_transform(dfrenamed[['Hepatitis B']])
dfrenamed['IMC'] = imputer.fit_transform(dfrenamed[['IMC']])
dfrenamed['Polio'] = imputer.fit_transform(dfrenamed[['Polio']])
dfrenamed['Gasto total'] = imputer.fit_transform(dfrenamed[['Gasto total']])
dfrenamed['Difteria'] = imputer.fit_transform(dfrenamed[['Difteria']])
dfrenamed['PIBPC'] = imputer.fit_transform(dfrenamed[['PIBPC']])
dfrenamed['Población'] = imputer.fit_transform(dfrenamed[['Población']])
dfrenamed['Delgadez 1-19 años'] = imputer.fit_transform(dfrenamed[['Delgadez 1-19 años']])
dfrenamed['Delgadez 5-9 años'] = imputer.fit_transform(dfrenamed[['Delgadez 5-9 años']])
dfrenamed['Indice de desarrollo humano'] = imputer.fit_transform(dfrenamed[['Indice de desarrollo humano']])
dfrenamed['Escolaridad'] = imputer.fit_transform(dfrenamed[['Escolaridad']])

dfrenamed.isnull().sum()
# Out:
# País                             0
# Año                              0
# Estado de desarrollo             0
# Esperanza de vida                0
# Mortalidad adulta                0
# Muertes infantiles               0
# Alcohol                          0
# Gasto porcentual                 0
# Hepatitis B                      0
# Sarampión                        0
# IMC                              0
# Muertes menores de cinco años    0
# Polio                            0
# Gasto total                      0
# Difteria                         0
# VIH/SIDA                         0
# PIBPC                            0
# Población                        0
# Delgadez 1-19 años               0
# Delgadez 5-9 años                0
# Indice de desarrollo humano      0
# Escolaridad                      0
# dtype: int64

# %%
dfrenamed.head()
# Out:
#           País   Año Estado de desarrollo  Esperanza de vida  \
# 0  Afghanistan  2015           Developing               65.0
# 1  Afghanistan  2014           Developing               59.9
# 2  Afghanistan  2013           Developing               59.9
# 3  Afghanistan  2012           Developing               59.5
# 4  Afghanistan  2011           Developing               59.2
#
#    Mortalidad adulta  Muertes infantiles  Alcohol  Gasto porcentual  \
# 0              263.0                  62     0.01         71.279624
# 1              271.0                  64     0.01         73.523582
# 2              268.0                  66     0.01         73.219243
# 3              272.0                  69     0.01         78.184215
# 4              275.0                  71     0.01          7.097109
#
#    Hepatitis B  Sarampión  ...  Polio  Gasto total  Difteria  VIH/SIDA  \
# 0         65.0       1154  ...    6.0         8.16      65.0       0.1
# ...

# %%
plt.figure()
sns.histplot(data=dfrenamed,
              x = 'Esperanza de vida',
              alpha = 0.6,
              edgecolor = '#07DAA7',
              stat = 'count',
              bins = 20,
              hue = 'Estado de desarrollo')
# Out:
# <Axes: xlabel='Esperanza de vida', ylabel='Count'>

# %%
df_numeric = dfrenamed.select_dtypes(include=['Float64','int64'])
df_numeric.corr().head()

plt.figure(figsize=(18,10))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt=".3f")
plt.title('Matriz de Correlacion')
plt.show()

# %%
latam = [
    'Argentina', 'Bolivia', 'Brasil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'República Dominicana',
    'Ecuador', 'El Salvador', 'Guatemala', 'Honduras', 'México', 'Nicaragua', 'Panamá', 'Paraguay',
    'Perú', 'Uruguay', 'Venezuela'
]

dfrenamed['Latam'] = dfrenamed['País'].isin(latam)

dfrenamed[['País','Latam']].head()
# Out:
#           País  Latam
# 0  Afghanistan  False
# 1  Afghanistan  False
# 2  Afghanistan  False
# 3  Afghanistan  False
# 4  Afghanistan  False

# %%
sns.set_theme(style='ticks')

f, ax = plt.subplots(figsize=(10,8))

dfplot = dfrenamed[dfrenamed['Latam'] == True]

sns.boxplot(
    dfplot, x = 'Esperanza de vida', y="País", whis=[0, 100], width=.6)

sns.stripplot(dfplot, x='Esperanza de vida', y='País', size=4, color='.3', linewidth=0)

ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)

# %% [markdown]
# ¿Cómo influyen los factores socioeconómicos (como el PIB per cápita y el gasto en salud) en la esperanza de vida de los diferentes países?

# %%
df= dfrenamed[['PIBPC', 'Gasto porcentual', 'Esperanza de vida']].dropna()

correlation_matrix = df.corr()
print(correlation_matrix)

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='PIBPC', y='Esperanza de vida')
plt.title('Relación entre PIB per cápita y Esperanza de Vida')
plt.xlabel('PIB per cápita')
plt.ylabel('Esperanza de Vida')
plt.show()

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='PIBPC', y='Esperanza de vida', hue='Gasto porcentual', palette='coolwarm')
plt.title('Esperanza de vida en función del PIB per capita y Gasto en Salud')
plt.show()
# Out:
#                       PIBPC  Gasto porcentual  Esperanza de vida
# PIBPC              1.000000          0.888140           0.430493
# Gasto porcentual   0.888140          1.000000           0.381791
# Esperanza de vida  0.430493          0.381791           1.000000

# %% [markdown]
# ¿Cómo influyen los factores socioeconómicos en LATAM?
# Gasto Porcentual // Producto Interno Bruto pér Capita // Esperanza de vida
#
# El Gasto Porcentual lo comprendemos como el gasto que se desprende de PIBpc (Producto interno Bruto per capita) en materia de Salud.

# %%
filtrado = dfrenamed[dfrenamed['Latam']]

plt.figure(figsize=(10,6))
sns.scatterplot(data=filtrado, x='PIBPC', y='Esperanza de vida', hue='Gasto porcentual', size='Gasto porcentual', sizes=(20,200), palette='coolwarm')
plt.title('Esperanza de vida en función del PIB per capita y Gasto en Salud (LATAM)')
plt.show()

# %% [markdown]
# Podemos observar una relacion positiva entre PIBpc y Esperanza de vida, el Gasto en salud es un refuerzo en el indicador de la Esperanza de vida.
# Entendemos que el desarrollo economico de los individuos impacta positivamente en su longevidad, como asi tambien la inversion directa en salud.
#
# Tanto en LATAM, como en todo el mundo, el patron es correlativo. Mayor ingreso per capita, mayor inversion en salud, mas espectativa de vida.

# %% [markdown]
# ¿Y si observamos el gasto del gobierno en materia de salud?
#
# Gasto total: Gasto de las administraciones públicas en sanidad como porcentaje del gasto público total (%)
#
# Ponemos en contraste, el Gasto Total (Administracion), Gasto Porcentual (Per Capita) y la Esperanza de vida

# %%
print(dfrenamed['Gasto total'].min())
print(dfrenamed['Gasto total'].median())
print(dfrenamed['Gasto total'].max())
print(dfrenamed['Gasto total'].mean())
# Out:
# 0.37
# 5.9381895280235995
# 17.6
# 5.938189528023599

# %%
filtrado = dfrenamed[dfrenamed['Latam']]

plt.figure(figsize=(10,6))
sns.scatterplot(data=filtrado, x='Esperanza de vida', y='Gasto total', hue='Gasto porcentual', size='Gasto porcentual', sizes=(20,200), palette='coolwarm')
plt.title('Esperanza de vida en función del PIB per capita y Gasto en Salud (LATAM)')
plt.show()

# %% [markdown]
# Las conclusiones observadas, son similares al resto.
# Mayor gasto administrativo, nos posiciona en una mayor esperanza de vida, como tambien un mayor gasto (per capita) en materia de salud.

# %% [markdown]
# ¿Cómo afecta la vacunación infantil (Hepatitis B, Polio, Difteria) a la esperanza de vida y la mortalidad infantil? en LATAM

# %%
def categorizar_inmunizacion(valor):
    if valor <= 40:
        return 'Baja inmunización'
    elif 40 < valor <= 70:
        return 'Inmunización media'
    elif 70 < valor <= 90:
        return 'Alta inmunización'
    else:
        return 'Inmunización completa'

dfrenamed['Hepatitis_B_Nivel'] = dfrenamed['Hepatitis B'].apply(categorizar_inmunizacion)
dfrenamed['Polio_Nivel'] = dfrenamed['Polio'].apply(categorizar_inmunizacion)
dfrenamed['Difteria_Nivel'] = dfrenamed['Difteria'].apply(categorizar_inmunizacion)

dfrenamed[['País', 'Hepatitis_B_Nivel', 'Polio_Nivel', 'Difteria_Nivel']].head()
# Out:
#           País   Hepatitis_B_Nivel         Polio_Nivel      Difteria_Nivel
# 0  Afghanistan  Inmunización media   Baja inmunización  Inmunización media
# 1  Afghanistan  Inmunización media  Inmunización media  Inmunización media
# 2  Afghanistan  Inmunización media  Inmunización media  Inmunización media
# 3  Afghanistan  Inmunización media  Inmunización media  Inmunización media
# 4  Afghanistan  Inmunización media  Inmunización media  Inmunización media

# %%
df_latam = dfrenamed[dfrenamed['Latam']== True]

enfermedades = ['Hepatitis B', 'Polio', 'Difteria']
niveles_inmunizacion = ['Hepatitis_B_Nivel', 'Polio_Nivel', 'Difteria_Nivel']

fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

for i, enfermedad in enumerate(enfermedades):
    sns.boxplot(x=niveles_inmunizacion[i], y='Esperanza de vida', data=df_latam, ax=axes[i], hue=niveles_inmunizacion[i])
    axes[i].set_title(f'Esperanza de Vida vs {enfermedad}')
    axes[i].set_xlabel(f'Nivel de Inmunización de {enfermedad}')
    axes[i].set_ylabel('Esperanza de Vida')

plt.tight_layout()
plt.show()

# %%
enfermedades = ['Hepatitis B', 'Polio', 'Difteria']
niveles_inmunizacion = ['Hepatitis_B_Nivel', 'Polio_Nivel', 'Difteria_Nivel']

fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

for i, enfermedad in enumerate(enfermedades):
    sns.boxplot(x=niveles_inmunizacion[i], y='Muertes infantiles', data=df_latam, ax=axes[i], hue=niveles_inmunizacion[i])
    axes[i].set_title(f'Mortalidad infantil vs {enfermedad}')
    axes[i].set_xlabel(f'Nivel de Inmunización de {enfermedad}')
    axes[i].set_ylabel('Mortalidad Infantil')

plt.tight_layout()
plt.show()

# %% [markdown]
# Se puede observar que en funcion de una mejor inmunizacion a las diferentes enfermedades la esperanza de vida de cada nacion, es mayor, aunque tambien asi, se pueden observar algunos outliners.
# Lo mismo interviene en la Mortalidad infantil, hay una relacion entre la mayor inmunizacion y la disminucion de la misma, pero se pueden observar casos extremos.

# %% [markdown]
# Observamos las relaciones entre la Esperanza de vida, Nivel de escolaridad, IMC y Consumo de Alcohol.

# %%
# Filtrar solo los datos de Latinoamérica si es necesario
df_latam = dfrenamed[dfrenamed['Latam'] == True]

# Crear el scatter plot
plt.figure(figsize=(7, 6))
scatter = sns.scatterplot(
    x='Alcohol', 
    y='Esperanza de vida', 
    hue='IMC', 
    size='IMC',
    sizes=(20, 200), 
    data=dfrenamed, 
    palette='coolwarm'
)

plt.title('Relación entre Consumo de Alcohol, Esperanza de Vida e IMC (World)')
plt.xlabel('Consumo de Alcohol per cápita (litros)')
plt.ylabel('Esperanza de Vida (Años)')

plt.figure(figsize=(7,6))
scatter = sns.scatterplot(
    x ='Alcohol',
    y ='Esperanza de vida',
    hue ='IMC',
    size='IMC',
    sizes=(20,200),
    data =df_latam,
    palette='coolwarm'
)

# Añadir etiquetas y título
plt.title('Relación entre Consumo de Alcohol, Esperanza de Vida e IMC (Latam)')
plt.xlabel('Consumo de Alcohol per cápita (litros)')
plt.ylabel('Esperanza de Vida (Años)')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# El IMC tiene una relacion positiva con la Esperanza de vida, el consumo de alcohol, no tanto.
# Se puede entender que un menor IMC afecta directamente la espectativa de vida, no es un factor puntual, el consumo de alcohol.

# %%
# Filtrar solo los datos de Latinoamérica, si es necesario
df_latam = dfrenamed[dfrenamed['Latam'] == True]

# Crear el scatter plot
plt.figure(figsize=(7, 6))
sns.scatterplot(data=dfrenamed, x='Escolaridad', y='Esperanza de vida', size='Alcohol', sizes=(20, 200), hue='Alcohol', palette='coolwarm', alpha=0.7)

# Añadir etiquetas y título
plt.title('Relacion entre Escolaridad, Consumo de Alcohol y Esperanza de Vida (World)')
plt.xlabel('Escolaridad(Años de estudios)')
plt.ylabel('Esperanza de Vida (Años)')
plt.legend(title='Alcohol', loc='best')

plt.figure(figsize=(7, 6))
sns.scatterplot(data=df_latam, x='Escolaridad', y='Esperanza de vida', size='Alcohol', sizes=(20, 200), hue='Alcohol', palette='coolwarm', alpha=0.7)

# Añadir etiquetas y título
plt.title('Relacion entre Escolaridad, Consumo de Alcohol y Esperanza de Vida (LATAM)')
plt.xlabel('Escolaridad(Años de estudios)')
plt.ylabel('Esperanza de Vida (Años)')
plt.legend(title='Alcohol', loc='best')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# Los Años de estudios tiene una fuerte presencia en la Esperanza de vida de las sociedades, consultadas sobre el consumo de alcohol, no parece tener una relacion importante en la determinacion del nivel de estudios de los individuos, como tampoco en la Esperanza de vida. Aunque reconocemos es un factor de riesgo.
